# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# # Dia 03/20 - Pandas

# %%
#Loading base of datas
df = pd.read_csv('http://www.ppgia.pucpr.br/~jean.barddal/datascience/kobe_shots.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30697 entries, 0 to 30696
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   action_type         30697 non-null  object
#  1   combined_shot_type  30697 non-null  object
#  2   game_event_id       30697 non-null  int64
#  3   game_id             30697 non-null  int64
#  4   lat                 30697 non-null  float64
#  5   loc_x               30697 non-null  int64
#  6   loc_y               30697 non-null  int64
#  7   lon                 30697 non-null  float64
#  8   minutes_remaining   30697 non-null  int64
#  9   period              30697 non-null  int64
#  10  playoffs            30697 non-null  int64
#  11  season              30697 non-null  object
#  12  seconds_remaining   30697 non-null  int64
#  13  shot_distance       30697 non-null  int64
#  14  shot_made_flag      25697 non-null  float64
#  15  shot_type           30697 non-null  object
#  16  shot_zone_area      30697 non-null  object
#  17  shot_zone_basic     30697 non-null  object
#  18  shot_zone_range     30697 non-null  object
#  19  team_id             30697 non-null  int64
#  20  team_name           30697 non-null  object
#  21  game_date           30697 non-null  object
#  22  matchup             30697 non-null  object
#  23  opponent            30697 non-null  object
#  24  shot_id             30697 non-null  int64
# dtypes: float64(3), int64(11), object(11)
# memory usage: 5.9+ MB

# %%
#get number row and cows -> shape
n_rows,n_cows = df.shape
print(n_rows)
print(n_cows)
# Out:
# 30697
# 25

# %%
#show the beging  of dataset
df.head(5)
# Out:
#          action_type combined_shot_type  game_event_id   game_id      lat  \
# 0          Jump Shot          Jump Shot             10  20000012  33.9723
# 1          Jump Shot          Jump Shot             12  20000012  34.0443
# 2          Jump Shot          Jump Shot             35  20000012  33.9093
# 3          Jump Shot          Jump Shot             43  20000012  33.8693
# 4  Driving Dunk Shot               Dunk            155  20000012  34.0443
#
#    loc_x  loc_y       lon  minutes_remaining  period  ...       shot_type  \
# 0    167     72 -118.1028                 10       1  ...  2PT Field Goal
# 1   -157      0 -118.4268                 10       1  ...  2PT Field Goal
# 2   -101    135 -118.3708                  7       1  ...  2PT Field Goal
# 3    138    175 -118.1318                  6       1  ...  2PT Field Goal
# 4      0      0 -118.2698                  6       2  ...  2PT Field Goal
#
#           shot_zone_area  shot_zone_basic  shot_zone_range     team_id  \
# 0          Right Side(R)        Mid-Range        16-24 ft.  1610612747
# 1           Left Side(L)        Mid-Range         8-16 ft.  1610612747
# 2   Left Side Center(LC)        Mid-Range        16-24 ft.  1610612747
# 3  Right Side Center(RC)        Mid-Range        16-24 ft.  1610612747
# 4              Center(C)  Restricted Area  Less Than 8 ft.  1610612747
#
#             team_name   game_date    matchup opponent  shot_id
# 0  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        1
# 1  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        2
# 2  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        3
# 3  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        4
# 4  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        5
#
# [5 rows x 25 columns]

# %%
#show the end of dataset 
df.tail(5)
# Out:
#              action_type combined_shot_type  game_event_id   game_id      lat  \
# 30692          Jump Shot          Jump Shot            397  49900088  33.9963
# 30693           Tip Shot           Tip Shot            398  49900088  34.0443
# 30694  Running Jump Shot          Jump Shot            426  49900088  33.8783
# 30695          Jump Shot          Jump Shot            448  49900088  33.7773
# 30696          Jump Shot          Jump Shot            471  49900088  33.9723
#
#        loc_x  loc_y       lon  minutes_remaining  period  ...       shot_type  \
# 30692      1     48 -118.2688                  6       4  ...  2PT Field Goal
# 30693      0      0 -118.2698                  6       4  ...  2PT Field Goal
# 30694   -134    166 -118.4038                  3       4  ...  2PT Field Goal
# 30695     31    267 -118.2388                  2       4  ...  3PT Field Goal
# 30696      1     72 -118.2688                  0       4  ...  2PT Field Goal
#
#              shot_zone_area        shot_zone_basic  shot_zone_range  \
# 30692             Center(C)  In The Paint (Non-RA)  Less Than 8 ft.
# 30693             Center(C)        Restricted Area  Less Than 8 ft.
# 30694  Left Side Center(LC)              Mid-Range        16-24 ft.
# 30695             Center(C)      Above the Break 3          24+ ft.
# 30696             Center(C)  In The Paint (Non-RA)  Less Than 8 ft.
#
#           team_id           team_name   game_date      matchup opponent  \
# 30692  1610612747  Los Angeles Lakers  2000-06-19  LAL vs. IND      IND
# 30693  1610612747  Los Angeles Lakers  2000-06-19  LAL vs. IND      IND
# 30694  1610612747  Los Angeles Lakers  2000-06-19  LAL vs. IND      IND
# 30695  1610612747  Los Angeles Lakers  2000-06-19  LAL vs. IND      IND
# 30696  1610612747  Los Angeles Lakers  2000-06-19  LAL vs. IND      IND
#
#        shot_id
# 30692    30693
# 30693    30694
# 30694    30695
# 30695    30696
# 30696    30697
#
# [5 rows x 25 columns]

# %%
# select cow action_type
df['action_type']
# Out:
# 0                Jump Shot
# 1                Jump Shot
# 2                Jump Shot
# 3                Jump Shot
# 4        Driving Dunk Shot
#                ...
# 30692            Jump Shot
# 30693             Tip Shot
# 30694    Running Jump Shot
# 30695            Jump Shot
# 30696            Jump Shot
# Name: action_type, Length: 30697, dtype: object

# %%
#select action_type and period
df[['action_type','period']]
# Out:
#              action_type  period
# 0              Jump Shot       1
# 1              Jump Shot       1
# 2              Jump Shot       1
# 3              Jump Shot       1
# 4      Driving Dunk Shot       2
# ...                  ...     ...
# 30692          Jump Shot       4
# 30693           Tip Shot       4
# 30694  Running Jump Shot       4
# 30695          Jump Shot       4
# 30696          Jump Shot       4
#
# [30697 rows x 2 columns]

# %%
# describe -> static of number columns
df.describe()
# Out:
#        game_event_id       game_id           lat         loc_x         loc_y  \
# count   30697.000000  3.069700e+04  30697.000000  30697.000000  30697.000000
# mean      249.190800  2.476407e+07     33.953192      7.110499     91.107535
# std       150.003712  7.755175e+06      0.087791    110.124578     87.791361
# min         2.000000  2.000001e+07     33.253300   -250.000000    -44.000000
# 25%       110.000000  2.050008e+07     33.884300    -68.000000      4.000000
# 50%       253.000000  2.090035e+07     33.970300      0.000000     74.000000
# 75%       368.000000  2.960047e+07     34.040300     95.000000    160.000000
# max       659.000000  4.990009e+07     34.088300    248.000000    791.000000
#
#                 lon  minutes_remaining        period      playoffs  \
# count  30697.000000       30697.000000  30697.000000  30697.000000
# mean    -118.262690           4.885624      2.519432      0.146562
# std        0.110125           3.449897      1.153665      0.353674
# min     -118.519800           0.000000      1.000000      0.000000
# 25%     -118.337800           2.000000      1.000000      0.000000
# 50%     -118.269800           5.000000      3.000000      0.000000
# 75%     -118.174800           8.000000      3.000000      0.000000
# max     -118.021800          11.000000      7.000000      1.000000
#
#        seconds_remaining  shot_distance  shot_made_flag       team_id  \
# count       30697.000000   30697.000000    25697.000000  3.069700e+04
# mean           28.365085      13.437437        0.446161  1.610613e+09
# std            17.478949       9.374189        0.497103  0.000000e+00
# min             0.000000       0.000000        0.000000  1.610613e+09
# 25%            13.000000       5.000000        0.000000  1.610613e+09
# 50%            28.000000      15.000000        0.000000  1.610613e+09
# 75%            43.000000      21.000000        1.000000  1.610613e+09
# max            59.000000      79.000000        1.000000  1.610613e+09
#
#             shot_id
# count  30697.000000
# mean   15349.000000
# std     8861.604943
# min        1.000000
# 25%     7675.000000
# 50%    15349.000000
# 75%    23023.000000
# max    30697.000000

# %%
#select lines
#afeter line 10 at 12
df[10:12]
# Out:
#    action_type combined_shot_type  game_event_id   game_id      lat  loc_x  \
# 10   Jump Shot          Jump Shot            309  20000012  33.8063    -94
# 11   Jump Shot          Jump Shot              4  20000019  33.9173    121
#
#     loc_y       lon  minutes_remaining  period  ...       shot_type  \
# 10    238 -118.3638                  1       3  ...  3PT Field Goal
# 11    127 -118.1488                 11       1  ...  2PT Field Goal
#
#            shot_zone_area    shot_zone_basic  shot_zone_range     team_id  \
# 10   Left Side Center(LC)  Above the Break 3          24+ ft.  1610612747
# 11  Right Side Center(RC)          Mid-Range        16-24 ft.  1610612747
#
#              team_name   game_date      matchup opponent  shot_id
# 10  Los Angeles Lakers  2000-10-31    LAL @ POR      POR       11
# 11  Los Angeles Lakers  2000-11-01  LAL vs. UTA      UTA       12
#
# [2 rows x 25 columns]

# %%
## Commands 
# loc:
# select  instance  by index
# iloc:
# select instance  by position
# ix (deprect):
# both

print(df.loc[0])
print("\n\n")
print(df.iloc[0])
# Out:
# action_type                    Jump Shot
# combined_shot_type             Jump Shot
# game_event_id                         10
# game_id                         20000012
# lat                              33.9723
# loc_x                                167
# loc_y                                 72
# lon                             -118.103
# minutes_remaining                     10
# period                                 1
# playoffs                               0
# season                           2000-01
# seconds_remaining                     27
# shot_distance                         18
# shot_made_flag                       NaN
# shot_type                 2PT Field Goal
# shot_zone_area             Right Side(R)
# shot_zone_basic                Mid-Range
# shot_zone_range                16-24 ft.
# team_id                       1610612747
# team_name             Los Angeles Lakers
# game_date                     2000-10-31
# matchup                        LAL @ POR
# opponent                             POR
# shot_id                                1
# Name: 0, dtype: object
#
#
#
# action_type                    Jump Shot
# combined_shot_type             Jump Shot
# game_event_id                         10
# game_id                         20000012
# lat                              33.9723
# loc_x                                167
# loc_y                                 72
# lon                             -118.103
# minutes_remaining                     10
# period                                 1
# playoffs                               0
# season                           2000-01
# seconds_remaining                     27
# shot_distance                         18
# shot_made_flag                       NaN
# shot_type                 2PT Field Goal
# shot_zone_area             Right Side(R)
# shot_zone_basic                Mid-Range
# shot_zone_range                16-24 ft.
# team_id                       1610612747
# team_name             Los Angeles Lakers
# game_date                     2000-10-31
# matchup                        LAL @ POR
# opponent                             POR
# shot_id                                1
# Name: 0, dtype: object

# %%
#erase first line
#axis = 0 line
#axis = 1 clow
#this command make a view of table if the inplace is False or Null
df.drop(0, axis=0, inplace=True)

# %%
df.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-130-7eaf75073732> in <module>
# ----> 1 df.loc[0]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1963         # fall thru to straight lookup
#    1964         self._validate_key(key, axis)
# -> 1965         return self._get_label(key, axis=axis)
#    1966
#    1967
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     623             raise IndexingError("no slices here, handle elsewhere")
#     624
# --> 625         return self.obj._xs(label, axis=axis)
#     626
#     627     def _get_loc(self, key: int, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3535             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3536         else:
# -> 3537             loc = self.index.get_loc(key)
#    3538
#    3539             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
df.iloc[0]
# Out:
# action_type                    Jump Shot
# combined_shot_type             Jump Shot
# game_event_id                         12
# game_id                         20000012
# lat                              34.0443
# loc_x                               -157
# loc_y                                  0
# lon                             -118.427
# minutes_remaining                     10
# period                                 1
# playoffs                               0
# season                           2000-01
# seconds_remaining                     22
# shot_distance                         15
# shot_made_flag                         0
# shot_type                 2PT Field Goal
# shot_zone_area              Left Side(L)
# shot_zone_basic                Mid-Range
# shot_zone_range                 8-16 ft.
# team_id                       1610612747
# team_name             Los Angeles Lakers
# game_date                     2000-10-31
# matchup                        LAL @ POR
# opponent                             POR
# shot_id                                2
# Name: 1, dtype: object

# %%
#creat new index from 0
df.reset_index()
# Out:
#        index        action_type combined_shot_type  game_event_id   game_id  \
# 0          1          Jump Shot          Jump Shot             12  20000012
# 1          2          Jump Shot          Jump Shot             35  20000012
# 2          3          Jump Shot          Jump Shot             43  20000012
# 3          4  Driving Dunk Shot               Dunk            155  20000012
# 4          5          Jump Shot          Jump Shot            244  20000012
# ...      ...                ...                ...            ...       ...
# 30691  30692          Jump Shot          Jump Shot            397  49900088
# 30692  30693           Tip Shot           Tip Shot            398  49900088
# 30693  30694  Running Jump Shot          Jump Shot            426  49900088
# 30694  30695          Jump Shot          Jump Shot            448  49900088
# 30695  30696          Jump Shot          Jump Shot            471  49900088
#
#            lat  loc_x  loc_y       lon  minutes_remaining  ...  \
# 0      34.0443   -157      0 -118.4268                 10  ...
# 1      33.9093   -101    135 -118.3708                  7  ...
# 2      33.8693    138    175 -118.1318                  6  ...
# 3      34.0443      0      0 -118.2698                  6  ...
# 4      34.0553   -145    -11 -118.4148                  9  ...
# ...        ...    ...    ...       ...                ...  ...
# 30691  33.9963      1     48 -118.2688                  6  ...
# 30692  34.0443      0      0 -118.2698                  6  ...
# 30693  33.8783   -134    166 -118.4038                  3  ...
# 30694  33.7773     31    267 -118.2388                  2  ...
# 30695  33.9723      1     72 -118.2688                  0  ...
#
#             shot_type         shot_zone_area        shot_zone_basic  \
# 0      2PT Field Goal           Left Side(L)              Mid-Range
# 1      2PT Field Goal   Left Side Center(LC)              Mid-Range
# 2      2PT Field Goal  Right Side Center(RC)              Mid-Range
# 3      2PT Field Goal              Center(C)        Restricted Area
# 4      2PT Field Goal           Left Side(L)              Mid-Range
# ...               ...                    ...                    ...
# 30691  2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 30692  2PT Field Goal              Center(C)        Restricted Area
# 30693  2PT Field Goal   Left Side Center(LC)              Mid-Range
# 30694  3PT Field Goal              Center(C)      Above the Break 3
# 30695  2PT Field Goal              Center(C)  In The Paint (Non-RA)
#
#        shot_zone_range     team_id           team_name   game_date  \
# 0             8-16 ft.  1610612747  Los Angeles Lakers  2000-10-31
# 1            16-24 ft.  1610612747  Los Angeles Lakers  2000-10-31
# 2            16-24 ft.  1610612747  Los Angeles Lakers  2000-10-31
# 3      Less Than 8 ft.  1610612747  Los Angeles Lakers  2000-10-31
# 4             8-16 ft.  1610612747  Los Angeles Lakers  2000-10-31
# ...                ...         ...                 ...         ...
# 30691  Less Than 8 ft.  1610612747  Los Angeles Lakers  2000-06-19
# 30692  Less Than 8 ft.  1610612747  Los Angeles Lakers  2000-06-19
# 30693        16-24 ft.  1610612747  Los Angeles Lakers  2000-06-19
# 30694          24+ ft.  1610612747  Los Angeles Lakers  2000-06-19
# 30695  Less Than 8 ft.  1610612747  Los Angeles Lakers  2000-06-19
#
#            matchup opponent shot_id
# 0        LAL @ POR      POR       2
# 1        LAL @ POR      POR       3
# 2        LAL @ POR      POR       4
# 3        LAL @ POR      POR       5
# 4        LAL @ POR      POR       6
# ...            ...      ...     ...
# 30691  LAL vs. IND      IND   30693
# 30692  LAL vs. IND      IND   30694
# 30693  LAL vs. IND      IND   30695
# 30694  LAL vs. IND      IND   30696
# 30695  LAL vs. IND      IND   30697
#
# [30696 rows x 26 columns]

# %%
#possibles values of shot_type
print(str(df['shot_type'].unique()) + "\n")
#Count of values of shot_type
print(str(df['shot_type'].nunique()) + "\n")
#Count line by of type
print(df['shot_type'].value_counts())
# Out:
# ['2PT Field Goal' '3PT Field Goal']
#
# 2
#
# 2PT Field Goal    24270
# 3PT Field Goal     6426
# Name: shot_type, dtype: int64

# %%
#Count lines of shot_type by filters
#Select of instances by value of shot_type iqual 2PT
#Select of instances by value of shot_type iqual 3PT
#Count both
df_2pt = df[df['shot_type'] == '2PT Field Goal']
df_3pt = df[df['shot_type'] == '3PT Field Goal']
print(len(df_2pt))
print("\n")
print(len(df_3pt))
# Out:
# 24270
#
#
# 6426

# %%
#Count lines the pich hit in 2pt
#& = AND 
#| = OR
#~ = NOT
mask = (df['shot_type'] == '2PT Field Goal') & (df['shot_made_flag'] == 1.0)
len(df[mask])
# Out:
# 9683

# %%
#max, min, mean, std, var
print(df['minutes_remaining'].max())
print(df['minutes_remaining'].min())
print(df['minutes_remaining'].mean())
print(df['minutes_remaining'].std())
print(df['minutes_remaining'].var())
# Out:
# 11
# 0
# 4.885457388584832
# 3.449830165385689
# 11.90132817000505

# %%
#median
np.median(df['minutes_remaining'])
# Out:
# 5.0

# %%
#mode
df.mode()['minutes_remaining'][0]
# Out:
# 0.0

# %%
#ording by period
df.sort_values('period', ascending=False).head(2)
# Out:
#               action_type combined_shot_type  game_event_id   game_id  \
# 10251           Jump Shot          Jump Shot            617  20600431
# 10250  Running Layup Shot              Layup            604  20600431
#
#            lat  loc_x  loc_y       lon  minutes_remaining  period  ...  \
# 10251  33.7943     -6    250 -118.2758                  1       7  ...
# 10250  34.0443      0      0 -118.2698                  2       7  ...
#
#             shot_type shot_zone_area    shot_zone_basic  shot_zone_range  \
# 10251  3PT Field Goal      Center(C)  Above the Break 3          24+ ft.
# 10250  2PT Field Goal      Center(C)    Restricted Area  Less Than 8 ft.
#
#           team_id           team_name   game_date    matchup opponent  shot_id
# 10251  1610612747  Los Angeles Lakers  2006-12-29  LAL @ CHA      CHA    10252
# 10250  1610612747  Los Angeles Lakers  2006-12-29  LAL @ CHA      CHA    10251
#
# [2 rows x 25 columns]

# %%
#creat a cloumn
df['game_event_id_sum'] =  df['game_event_id'] +50

# %%
#Apply function  in column
def is_home_game(x):
  if x.find('@') < 0:
    return  1
  else:
    return 0

df['home_game'] = df['matchup'].apply(is_home_game)
df.head(1)
# Out:
#   action_type combined_shot_type  game_event_id   game_id      lat  loc_x  \
# 1   Jump Shot          Jump Shot             12  20000012  34.0443   -157
#
#    loc_y       lon  minutes_remaining  period  ...  shot_zone_basic  \
# 1      0 -118.4268                 10       1  ...        Mid-Range
#
#   shot_zone_range     team_id           team_name   game_date    matchup  \
# 1        8-16 ft.  1610612747  Los Angeles Lakers  2000-10-31  LAL @ POR
#
#   opponent shot_id game_event_id_sum  home_game
# 1      POR       2                62          0
#
# [1 rows x 27 columns]

# %%
#Using lambda 
df['home_game_lambda'] = df['matchup'].apply(lambda x: 1 if (x.find('@') < 0) else 0)
df.head(1)
# Out:
#   action_type combined_shot_type  game_event_id   game_id      lat  loc_x  \
# 1   Jump Shot          Jump Shot             12  20000012  34.0443   -157
#
#    loc_y       lon  minutes_remaining  period  ...  shot_zone_range  \
# 1      0 -118.4268                 10       1  ...         8-16 ft.
#
#       team_id           team_name   game_date    matchup opponent shot_id  \
# 1  1610612747  Los Angeles Lakers  2000-10-31  LAL @ POR      POR       2
#
#   game_event_id_sum home_game  home_game_lambda
# 1                62         0                 0
#
# [1 rows x 28 columns]

# %%
#Home Work
def point_made(data):    
    if data[0] == 1.0:
      if data[1] == '2PT Field Goal':
        return 2
      else:
        return 3
    return 0
df['points_made'] = df[['shot_made_flag','shot_type']].apply(point_made,axis=1)

df
# Out:
#              action_type combined_shot_type  game_event_id   game_id      lat  \
# 1              Jump Shot          Jump Shot             12  20000012  34.0443
# 2              Jump Shot          Jump Shot             35  20000012  33.9093
# 3              Jump Shot          Jump Shot             43  20000012  33.8693
# 4      Driving Dunk Shot               Dunk            155  20000012  34.0443
# 5              Jump Shot          Jump Shot            244  20000012  34.0553
# ...                  ...                ...            ...       ...      ...
# 30692          Jump Shot          Jump Shot            397  49900088  33.9963
# 30693           Tip Shot           Tip Shot            398  49900088  34.0443
# 30694  Running Jump Shot          Jump Shot            426  49900088  33.8783
# 30695          Jump Shot          Jump Shot            448  49900088  33.7773
# 30696          Jump Shot          Jump Shot            471  49900088  33.9723
#
#        loc_x  loc_y       lon  minutes_remaining  period  ...     team_id  \
# 1       -157      0 -118.4268                 10       1  ...  1610612747
# 2       -101    135 -118.3708                  7       1  ...  1610612747
# 3        138    175 -118.1318                  6       1  ...  1610612747
# 4          0      0 -118.2698                  6       2  ...  1610612747
# 5       -145    -11 -118.4148                  9       3  ...  1610612747
# ...      ...    ...       ...                ...     ...  ...         ...
# 30692      1     48 -118.2688                  6       4  ...  1610612747
# 30693      0      0 -118.2698                  6       4  ...  1610612747
# 30694   -134    166 -118.4038                  3       4  ...  1610612747
# 30695     31    267 -118.2388                  2       4  ...  1610612747
# 30696      1     72 -118.2688                  0       4  ...  1610612747
#
#                 team_name   game_date      matchup  opponent shot_id  \
# 1      Los Angeles Lakers  2000-10-31    LAL @ POR       POR       2
# 2      Los Angeles Lakers  2000-10-31    LAL @ POR       POR       3
# 3      Los Angeles Lakers  2000-10-31    LAL @ POR       POR       4
# 4      Los Angeles Lakers  2000-10-31    LAL @ POR       POR       5
# 5      Los Angeles Lakers  2000-10-31    LAL @ POR       POR       6
# ...                   ...         ...          ...       ...     ...
# 30692  Los Angeles Lakers  2000-06-19  LAL vs. IND       IND   30693
# 30693  Los Angeles Lakers  2000-06-19  LAL vs. IND       IND   30694
# 30694  Los Angeles Lakers  2000-06-19  LAL vs. IND       IND   30695
# 30695  Los Angeles Lakers  2000-06-19  LAL vs. IND       IND   30696
# 30696  Los Angeles Lakers  2000-06-19  LAL vs. IND       IND   30697
#
#       game_event_id_sum home_game home_game_lambda  points_made
# 1                    62         0                0            0
# 2                    85         0                0            2
# 3                    93         0                0            0
# 4                   205         0                0            2
# 5                   294         0                0            0
# ...                 ...       ...              ...          ...
# 30692               447         1                1            0
# 30693               448         1                1            0
# 30694               476         1                1            2
# 30695               498         1                1            0
# 30696               521         1                1            0
#
# [30696 rows x 29 columns]

# %% [markdown]
# # Dia 10/08 - Estatística descritiva de dados

# %%
df = pd.read_csv('http://www.ppgia.pucpr.br/~jean.barddal/datascience/Salaries.csv')

# %%
df
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0             1      Prof          B             19           18  Male  139750
# 1             2      Prof          B             20           16  Male  173200
# 2             3  AsstProf          B              4            3  Male   79750
# 3             4      Prof          B             45           39  Male  115000
# 4             5      Prof          B             40           41  Male  141500
# ..          ...       ...        ...            ...          ...   ...     ...
# 392         393      Prof          A             33           30  Male  103106
# 393         394      Prof          A             31           19  Male  150564
# 394         395      Prof          A             42           25  Male  101738
# 395         396      Prof          A             25           15  Male   95329
# 396         397  AsstProf          A              8            4  Male   81035
#
# [397 rows x 7 columns]

# %%
df.drop('Unnamed: 0',axis= 1, inplace=True)

# %%
df.head(5)
# Out:
#        rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0      Prof          B             19           18  Male  139750
# 1      Prof          B             20           16  Male  173200
# 2  AsstProf          B              4            3  Male   79750
# 3      Prof          B             45           39  Male  115000
# 4      Prof          B             40           41  Male  141500

# %%
df['rank'].unique()
# Out:
# array(['Prof', 'AsstProf', 'AssocProf'], dtype=object)

# %%
df['sex'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
## Calculando maior Salario, menor salario e salario medio por rank
df.groupby('rank')['salary'].mean()
# Out:
# rank
# AssocProf     93876.437500
# AsstProf      80775.985075
# Prof         126772.109023
# Name: salary, dtype: float64

# %%
df.groupby('rank')['salary'].min()
# Out:
# rank
# AssocProf    62884
# AsstProf     63100
# Prof         57800
# Name: salary, dtype: int64

# %%
df.groupby('rank')['salary'].max()
# Out:
# rank
# AssocProf    126431
# AsstProf      97032
# Prof         231545
# Name: salary, dtype: int64

# %%
df.groupby('rank')['salary'].describe()
# Out:
#            count           mean           std      min        25%       50%  \
# rank
# AssocProf   64.0   93876.437500  13831.699844  62884.0   82475.00   95626.5
# AsstProf    67.0   80775.985075   8174.112637  63100.0   74000.00   79800.0
# Prof       266.0  126772.109023  27718.674999  57800.0  105975.25  123321.5
#
#                  75%       max
# rank
# AssocProf  104226.25  126431.0
# AsstProf    88597.50   97032.0
# Prof       145080.50  231545.0

# %%
df[df['rank']== 'Prof']['salary'].hist(bins=25) #histograma

# %%
df['salary'].hist(bins=25)

# %%
### Qual o comportamento dos salarios entre os sexos?
df.groupby('sex')['salary'].describe()
# Out:
#         count           mean           std      min      25%       50%  \
# sex
# Female   39.0  101002.410256  25952.127317  62884.0  77250.0  103750.0
# Male    358.0  115090.418994  30436.927344  57800.0  92000.0  108043.0
#
#               75%       max
# sex
# Female  117002.50  161101.0
# Male    134863.75  231545.0

# %%
### Qual o comportamento do salario perante sexo e rank?
df.groupby(['sex','rank'])['salary'].describe()
# Out:
#                   count           mean           std      min        25%  \
# sex    rank
# Female AssocProf   10.0   88512.800000  17965.286006  62884.0   73682.50
#        AsstProf    11.0   78049.909091   9371.996121  63100.0   73000.00
#        Prof        18.0  121967.611111  19619.582577  90450.0  109723.00
# Male   AssocProf   54.0   94869.703704  12890.817423  70000.0   83213.25
#        AsstProf    56.0   81311.464286   7901.342712  63900.0   74375.00
#        Prof       248.0  127120.822581  28213.807675  57800.0  105834.50
#
#                        50%        75%       max
# sex    rank
# Female AssocProf   90556.5  103933.00  109650.0
#        AsstProf    77000.0   79362.50   97032.0
#        Prof       120257.5  135000.00  161101.0
# Male   AssocProf   95626.5  104630.25  126431.0
#        AsstProf    80182.0   88802.50   95079.0
#        Prof       123996.0  145512.50  231545.0

# %%
df.corr()
# Out:
#                yrs.since.phd  yrs.service    salary
# yrs.since.phd       1.000000     0.909649  0.419231
# yrs.service         0.909649     1.000000  0.334745
# salary              0.419231     0.334745  1.000000

# %% [markdown]
# # Aula 17/08 - Análise univariada e multivariada de dados

# %%
df = pd.read_csv('http://www.ppgia.pucpr.br/~jean.barddal/datascience/titanic.csv')
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
#histograma
df['Age'].hist()

# %%
#histograma(seaborn) -> distplot(KDE -> probabilidade)
sns.distplot(df['Age'], kde=False, bins=10)
plt.show()

# %%
#grafico de barras(normalmente nao faz sentido para variaveis numericas)
sns.countplot(df['Age'])
plt.show()

# %%
#box-plot
sns.boxplot(df['Age'])
plt.show()
#whiskersÇ representam minimos e maximos "aceitaveis" (Método de Tukey)
#aula voltada para outliers

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
#violin plot
sns.violinplot(df['Age'])
plt.show()

# %%
# grafico de barra
sns.countplot(df['Embarked'])
plt.show()

# %%
#pie chart
df['Embarked'].dropna().value_counts().plot(kind='pie')

# %%
df['Embarked'].value_counts()df['Embarked'].value_counts()
# Out:
#   File "<ipython-input-170-cae8ede388da>", line 1
#     df['Embarked'].value_counts()df['Embarked'].value_counts()
#                                  ^
# SyntaxError: invalid syntax

# %%
# comparando as distribuicoes de idade por sobrevivencia ou nao
sns.boxplot(x = df['Survived'], y = df['Age'])
plt.show()

# %%
#comparando as distribuicoes de idades por sexo 
sns.boxplot(x = df['Sex'], y = df['Age'])
plt.show()

# %%
# Criar a base
df = pd.DataFrame({
    'x' : np.random.normal(10, 1.2, 20000),
    'y' : np.random.normal(10, 1.2, 20000),
    'group' : np.repeat('A', 20000)
})

tmp1 = pd.DataFrame({
    'x' : np.random.normal(14.5, 1.2, 20000),
    'y' : np.random.normal(14.5, 1.2, 20000),
    'group' : np.repeat('B', 20000)
})

tmp2 = pd.DataFrame({
    'x' : np.random.normal(9.5, 1.5, 20000),
    'y' : np.random.normal(15.5, 1.5, 20000),
    'group' : np.repeat('C', 20000)
})

# concatenating the data
df = df.append(tmp1).append(tmp2)

# %%
df.head(5)
# Out:
#            x          y group
# 0  10.614453  11.845480     A
# 1  10.053460  12.561407     A
# 2   8.722489   9.006004     A
# 3   7.882735   8.863061     A
# 4  10.123661  10.419210     A

# %%
df.describe()
# Out:
#                   x             y
# count  60000.000000  60000.000000
# mean      11.334232     13.327875
# std        2.597086      2.723942
# min        3.973183      5.549210
# 25%        9.350687     10.788312
# 50%       10.693462     14.010476
# 75%       13.706179     15.399620
# max       19.121364     21.322119

# %%
#analisando cada variavel de forma individual
sns.distplot(df['x'])
plt.show()

# %%
#analisando cada variavel de forma individual
sns.distplot(df['y'])
plt.show()

# %%
#overploting
sns.scatterplot(df['x'],df['y'])
plt.show()

# %%
#mudar tamanho das bolinhas
sns.scatterplot(df['x'],df['y'], s=2)
plt.show()

# %%
#transparencia
sns.scatterplot(df['x'],df['y'], alpha=0.01)
plt.show()

# %%
#densidade
sns.kdeplot(df['x'],df['y'], shade=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'x'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-212-955cf9be83ac> in <module>
#       1 #densidade
# ----> 2 sns.kdeplot(df['x'],df['y'], shade=True)
#       3 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'x'

# %%
#join plot
sns.jointplot(df['x'],df['y'],kind='kde')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'x'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-213-669740be5505> in <module>
#       1 #join plot
# ----> 2 sns.jointplot(df['x'],df['y'],kind='kde')
#       3 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'x'

# %%
#amostragem (sampling)
samp = df.sample(1000)
sns.scatterplot(samp['x'], samp['y'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-214-f87b81916ee9> in <module>
#       1 #amostragem (sampling)
# ----> 2 samp = df.sample(1000)
#       3 sns.scatterplot(samp['x'], samp['y'])
#       4 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    5059             )
#    5060
# -> 5061         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    5062         return self.take(locs, axis=axis)
#    5063
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %%
#enfase -> dar mais atencao a umm dos grupos
df_a = df[df['group']=='A']
df_restante = df[df['group']!='A']

sns.scatterplot(df_restante['x'],df_restante['y'], color='grey')
sns.scatterplot(df_a['x'],df_a['y'],color='green')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'group'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-215-f928493c0c20> in <module>
#       1 #enfase -> dar mais atencao a umm dos grupos
# ----> 2 df_a = df[df['group']=='A']
#       3 df_restante = df[df['group']!='A']
#       4
#       5 sns.scatterplot(df_restante['x'],df_restante['y'], color='grey')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'group'

# %%
#facet grids -> facetamento
#analisar o comportamento de x e y, por grupo
g = sns.FacetGrid(df, col='group', hue='group')
g = g.map(plt.scatter,'x','y')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'group'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-216-cca62396dd3b> in <module>
#       1 #facet grids -> facetamento
#       2 #analisar o comportamento de x e y, por grupo
# ----> 3 g = sns.FacetGrid(df, col='group', hue='group')
#       4 g = g.map(plt.scatter,'x','y')
#       5 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     248             hue_names = None
#     249         else:
# --> 250             hue_names = utils.categorical_order(data[hue], hue_order)
#     251
#     252         colors = self._get_palette(data, hue, hue_order, palette)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'group'

# %%
# Criando nova base de dados
a = np.concatenate([
                    np.random.normal(2, 4, 1000),
                    np.random.normal(4, 4, 1000),
                    np.random.normal(1, 2,  500),
                    np.random.normal(10, 2, 500),
                    np.random.normal(8, 4, 1000),
                    np.random.normal(10, 4, 1000)
])

df = pd.DataFrame({
    'x': np.repeat(range(1,6), 1000),
    'y': a
})

# %%
df.head(5)
# Out:
#    x         y
# 0  1 -8.607604
# 1  1  1.675657
# 2  1  5.934459
# 3  1 -0.692541
# 4  1  4.397048

# %%
#scannerplot
sns.scatterplot(df['x'],df['y'])
plt.show()

# %%
#stripplot
sns.stripplot(df['x'], df['y'], jitter=0.3, size=2)
plt.show()

# %%
#combinando boxplots com stripplots
sns.boxplot(df['x'], df['y'])
sns.stripplot(df['x'], df['y'], jitter=0.3, size=2, color='grey')
plt.show()

# %%
#combinando violin com stripplots
sns.violinplot(df['x'], df['y'])
sns.stripplot(df['x'], df['y'], jitter=0.3, size=2, color='grey')
plt.show()

# %%
#combinando swarm plots
sns.swarmplot(df['x'], df['y'])
plt.show()

# %% [markdown]
# # Aula 24/08 - Análise de correlações

# %%
df = pd.read_csv('http://www.ppgia.pucpr.br/~jean.barddal/datascience/meses_producao_custo.csv')

# %%
df
# Out:
#    Meses  litros  custo
# 0    Jan   20200  19000
# 1    Fev   16700  17000
# 2    Mar   14800  14000
# 3    Abr   16000  15000
# 4    Mai   12100  14000
# 5    Jun   13000  15000
# 6    Jul   11600  13000
# 7    Ago   15500  16000
# 8    Set   18900  18000
# 9    Out   20000  19000
# 10   Nov   22500  20000
# 11   Dez   23000  21000

# %%
df.corr(method = 'pearson')
# Out:
#           litros     custo
# litros  1.000000  0.969993
# custo   0.969993  1.000000

# %%
sns.scatterplot(df['litros'], df['custo'])
plt.show()

# %%
sns.regplot(df['litros'], df['custo'])
plt.show()

# %%
# Exemplo onde a correlação não funciona
x = np.linspace(-np.pi, 5*np.pi, 201) # Criando 200 pontos que variam de -pi a pi
y = np.sin(x)
g = sns.jointplot(x=x, y=y, kind='reg')
g.annotate(stats.pearsonr)
plt.show()
# Out:
# C:\Users\Diego\anaconda3\lib\site-packages\seaborn\axisgrid.py:1840: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
df.corr(method = 'spearman') # Valores muito próximos a pearson
# Out:
#           litros     custo
# litros  1.000000  0.970137
# custo   0.970137  1.000000

# %%
# Relação entre variáveis categóricas
df = pd.read_csv('http://www.ppgia.pucpr.br/~jean.barddal/datascience/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# existe relação entre sexo e porto de embarque?
ctab = pd.crosstab(df['Sex'], df['Embarked'], normalize='columns' )
sns.heatmap(ctab, annot=True, fmt='.2%')
plt.show()

# %%
# existe relação entre o porto de embarque para cada um dos sexos?
ctab = pd.crosstab(df['Sex'], df['Embarked'], normalize='index' )
sns.heatmap(ctab, annot=True, fmt='.2%')
plt.show()

# %%
# Relação entre Pclass e Porto
ctab = pd.crosstab(df['Pclass'], df['Embarked'], normalize = 'columns')
sns.heatmap(ctab, annot=True, fmt='g')
plt.show()

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Pclass'].isna().sum()
# Out:
# 0

# %%
# Há relação entre sexo e sobrevivência?
ctab = pd.crosstab(df['Sex'], df['Survived'], normalize='index')
sns.heatmap(ctab, annot=True, fmt='.2%')
plt.show()

# %%
# Como podemos visualizar se dentre os homens, os que mais sobreviveram eram crianças?
# sugestão: criar coluna nova(criança = sim/não)

df_crianca = df[(df['Sex']=='male')]
ctab = pd.crosstab(df_crianca['Survived']==1, df_crianca['Age']<=13,  normalize='columns')
sns.heatmap(ctab, annot=True, fmt='.2%')
plt.show()

# %% [markdown]
# ## Multicolinearidade

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df = pd.read_csv('http://www.ppgia.pucpr.br/~jean.barddal/datascience/ommlbd_familiar.csv',na_values=-9999)

# %%
df.head(2)
# Out:
#    HS_CPF  QTDPESSOASCASA  MENORRENDACASA  MAIORRENDACASA  SOMARENDACASA  \
# 0   23325             NaN             NaN             NaN            NaN
# 1  667198             NaN             NaN             NaN            NaN
#
#    MEDIARENDACASA  MAIORIDADECASA  MENORIDADECASA  MEDIAIDADECASA  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
#
#    INDICMENORDEIDADE  COBRANCABAIXOCASA  COBRANCAMEDIOCASA  COBRANCAALTACASA  \
# 0                NaN                NaN                NaN               NaN
# 1                NaN                NaN                NaN               NaN
#
#    SEGMENTACAOFINBAIXACASA  SEGMENTACAOFINMEDIACASA  SEGMENTACAOALTACASA  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
#
#    BOLSAFAMILIACASA  FUNCIONARIOPUBLICOCASA
# 0               NaN                     NaN
# 1               NaN                     NaN

# %%
df.corr()
# Out:
#                            HS_CPF  QTDPESSOASCASA  MENORRENDACASA  \
# HS_CPF                   1.000000        0.019929       -0.024549
# QTDPESSOASCASA           0.019929        1.000000       -0.183627
# MENORRENDACASA          -0.024549       -0.183627        1.000000
# MAIORRENDACASA          -0.020831        0.053948        0.352656
# SOMARENDACASA           -0.018844        0.252608        0.433097
# MEDIARENDACASA          -0.027608       -0.103643        0.615976
# MAIORIDADECASA           0.041364        0.259603        0.106155
# MENORIDADECASA           0.026502       -0.166085        0.269575
# MEDIAIDADECASA           0.035755       -0.033299        0.232897
# INDICMENORDEIDADE       -0.034576        0.115711       -0.074302
# COBRANCABAIXOCASA        0.072836        0.109687        0.012774
# COBRANCAMEDIOCASA        0.014370        0.033187        0.004359
# COBRANCAALTACASA         0.035500        0.031315       -0.006413
# SEGMENTACAOFINBAIXACASA  0.127453        0.078343       -0.010084
# SEGMENTACAOFINMEDIACASA  0.001258        0.010212       -0.000067
# SEGMENTACAOALTACASA      0.001693        0.002181        0.008744
# BOLSAFAMILIACASA         0.060586        0.248071       -0.226525
# FUNCIONARIOPUBLICOCASA   0.000733        0.078393        0.106405
#
#                          MAIORRENDACASA  SOMARENDACASA  MEDIARENDACASA  \
# HS_CPF                        -0.020831      -0.018844       -0.027608
# QTDPESSOASCASA                 0.053948       0.252608       -0.103643
# MENORRENDACASA                 0.352656       0.433097        0.615976
# MAIORRENDACASA                 1.000000       0.923269        0.917403
# SOMARENDACASA                  0.923269       1.000000        0.880107
# MEDIARENDACASA                 0.917403       0.880107        1.000000
# MAIORIDADECASA                 0.219026       0.285825        0.198684
# MENORIDADECASA                 0.144396       0.145600        0.230392
# MEDIAIDADECASA                 0.218736       0.244595        0.269323
# INDICMENORDEIDADE             -0.040999      -0.036681       -0.072104
# COBRANCABAIXOCASA              0.045489       0.073351        0.032249
# COBRANCAMEDIOCASA              0.015623       0.025266        0.011203
# COBRANCAALTACASA               0.003079       0.010955       -0.002031
# SEGMENTACAOFINBAIXACASA        0.004508       0.023593       -0.006555
# SEGMENTACAOFINMEDIACASA        0.008445       0.011624        0.006487
# SEGMENTACAOALTACASA            0.004686       0.006083        0.006899
# BOLSAFAMILIACASA              -0.208776      -0.189434       -0.257195
# FUNCIONARIOPUBLICOCASA         0.200532       0.230712        0.195284
#
#                          MAIORIDADECASA  MENORIDADECASA  MEDIAIDADECASA  \
# HS_CPF                         0.041364        0.026502        0.035755
# QTDPESSOASCASA                 0.259603       -0.166085       -0.033299
# MENORRENDACASA                 0.106155        0.269575        0.232897
# MAIORRENDACASA                 0.219026        0.144396        0.218736
# SOMARENDACASA                  0.285825        0.145600        0.244595
# MEDIARENDACASA                 0.198684        0.230392        0.269323
# MAIORIDADECASA                 1.000000        0.489634        0.836517
# MENORIDADECASA                 0.489634        1.000000        0.844348
# MEDIAIDADECASA                 0.836517        0.844348        1.000000
# INDICMENORDEIDADE             -0.121856       -0.227301       -0.218414
# COBRANCABAIXOCASA              0.064165        0.032271        0.046645
# COBRANCAMEDIOCASA              0.014462        0.008302        0.010607
# COBRANCAALTACASA               0.016789        0.009470        0.011476
# SEGMENTACAOFINBAIXACASA        0.028294        0.001591        0.009690
# SEGMENTACAOFINMEDIACASA        0.007349        0.003308        0.005007
# SEGMENTACAOALTACASA            0.002348       -0.000865        0.001161
# BOLSAFAMILIACASA              -0.056346       -0.091464       -0.121059
# FUNCIONARIOPUBLICOCASA         0.083808        0.031671        0.063364
#
#                          INDICMENORDEIDADE  COBRANCABAIXOCASA  \
# HS_CPF                           -0.034576           0.072836
# QTDPESSOASCASA                    0.115711           0.109687
# MENORRENDACASA                   -0.074302           0.012774
# MAIORRENDACASA                   -0.040999           0.045489
# SOMARENDACASA                    -0.036681           0.073351
# MEDIARENDACASA                   -0.072104           0.032249
# MAIORIDADECASA                   -0.121856           0.064165
# MENORIDADECASA                   -0.227301           0.032271
# MEDIAIDADECASA                   -0.218414           0.046645
# INDICMENORDEIDADE                 1.000000          -0.017177
# COBRANCABAIXOCASA                -0.017177           1.000000
# COBRANCAMEDIOCASA                -0.003565           0.020509
# COBRANCAALTACASA                 -0.004737           0.009353
# SEGMENTACAOFINBAIXACASA          -0.014751           0.035332
# SEGMENTACAOFINMEDIACASA          -0.003264           0.002501
# SEGMENTACAOALTACASA              -0.002418           0.003210
# BOLSAFAMILIACASA                  0.057522           0.019529
# FUNCIONARIOPUBLICOCASA           -0.013577           0.036508
#
#                          COBRANCAMEDIOCASA  COBRANCAALTACASA  \
# HS_CPF                            0.014370          0.035500
# QTDPESSOASCASA                    0.033187          0.031315
# MENORRENDACASA                    0.004359         -0.006413
# MAIORRENDACASA                    0.015623          0.003079
# SOMARENDACASA                     0.025266          0.010955
# MEDIARENDACASA                    0.011203         -0.002031
# MAIORIDADECASA                    0.014462          0.016789
# MENORIDADECASA                    0.008302          0.009470
# MEDIAIDADECASA                    0.010607          0.011476
# INDICMENORDEIDADE                -0.003565         -0.004737
# COBRANCABAIXOCASA                 0.020509          0.009353
# COBRANCAMEDIOCASA                 1.000000          0.008935
# COBRANCAALTACASA                  0.008935          1.000000
# SEGMENTACAOFINBAIXACASA           0.011154          0.012684
# SEGMENTACAOFINMEDIACASA           0.004628          0.001218
# SEGMENTACAOALTACASA              -0.000683         -0.000518
# BOLSAFAMILIACASA                  0.006306          0.015108
# FUNCIONARIOPUBLICOCASA            0.008356          0.004518
#
#                          SEGMENTACAOFINBAIXACASA  SEGMENTACAOFINMEDIACASA  \
# HS_CPF                                  0.127453                 0.001258
# QTDPESSOASCASA                          0.078343                 0.010212
# MENORRENDACASA                         -0.010084                -0.000067
# MAIORRENDACASA                          0.004508                 0.008445
# SOMARENDACASA                           0.023593                 0.011624
# MEDIARENDACASA                         -0.006555                 0.006487
# MAIORIDADECASA                          0.028294                 0.007349
# MENORIDADECASA                          0.001591                 0.003308
# MEDIAIDADECASA                          0.009690                 0.005007
# INDICMENORDEIDADE                      -0.014751                -0.003264
# COBRANCABAIXOCASA                       0.035332                 0.002501
# COBRANCAMEDIOCASA                       0.011154                 0.004628
# COBRANCAALTACASA                        0.012684                 0.001218
# SEGMENTACAOFINBAIXACASA                 1.000000                 0.022916
# SEGMENTACAOFINMEDIACASA                 0.022916                 1.000000
# SEGMENTACAOALTACASA                     0.013758                 0.018885
# BOLSAFAMILIACASA                        0.033430                 0.001256
# FUNCIONARIOPUBLICOCASA                  0.018393                 0.006513
#
#                          SEGMENTACAOALTACASA  BOLSAFAMILIACASA  \
# HS_CPF                              0.001693          0.060586
# QTDPESSOASCASA                      0.002181          0.248071
# MENORRENDACASA                      0.008744         -0.226525
# MAIORRENDACASA                      0.004686         -0.208776
# SOMARENDACASA                       0.006083         -0.189434
# MEDIARENDACASA                      0.006899         -0.257195
# MAIORIDADECASA                      0.002348         -0.056346
# MENORIDADECASA                     -0.000865         -0.091464
# MEDIAIDADECASA                      0.001161         -0.121059
# INDICMENORDEIDADE                  -0.002418          0.057522
# COBRANCABAIXOCASA                   0.003210          0.019529
# COBRANCAMEDIOCASA                  -0.000683          0.006306
# COBRANCAALTACASA                   -0.000518          0.015108
# SEGMENTACAOFINBAIXACASA             0.013758          0.033430
# SEGMENTACAOFINMEDIACASA             0.018885          0.001256
# SEGMENTACAOALTACASA                 1.000000          0.000170
# BOLSAFAMILIACASA                    0.000170          1.000000
# FUNCIONARIOPUBLICOCASA              0.002038         -0.083346
#
#                          FUNCIONARIOPUBLICOCASA
# HS_CPF                                 0.000733
# QTDPESSOASCASA                         0.078393
# MENORRENDACASA                         0.106405
# MAIORRENDACASA                         0.200532
# SOMARENDACASA                          0.230712
# MEDIARENDACASA                         0.195284
# MAIORIDADECASA                         0.083808
# MENORIDADECASA                         0.031671
# MEDIAIDADECASA                         0.063364
# INDICMENORDEIDADE                     -0.013577
# COBRANCABAIXOCASA                      0.036508
# COBRANCAMEDIOCASA                      0.008356
# COBRANCAALTACASA                       0.004518
# SEGMENTACAOFINBAIXACASA                0.018393
# SEGMENTACAOFINMEDIACASA                0.006513
# SEGMENTACAOALTACASA                    0.002038
# BOLSAFAMILIACASA                      -0.083346
# FUNCIONARIOPUBLICOCASA                 1.000000

# %%
plt.rcParams['figure.figsize'] = (12, 12)
plt.rcParams['font.size'] = 10

cor = df.corr()
sns.heatmap(cor, annot=True, fmt='.0%')
plt.show()

# %% [markdown]
# ## VIF
# - Se o VIF = 1, significa que a variável não possui correlação com as demais
# - Se o VIF > 5, então há uma correlação com várias outras variáveis
#
# DETALHE: O VIF só é calculado se não houverem valores faltantes
#
# Redes neurais, arvores de decisão, regressão logística -> NÃO se beneficiam de poucas variáveis correlacionadas entre si
#
# Ensembles -> random forest, xgboost: se beneficiam de variáveis correlacionadas
#
# (componente aleatoria -> ignoram correlações altas entre atributos).

# %%
# Imputação

# -> Substituir os valores faltantes pela média de cada coluna
df.fillna(df.mean(), inplace=True)

# %%
# Função para cálculo do VIF

def calc_vif(tabela):
    vif = pd.DataFrame()
    vif['variaveis'] = tabela.columns
    vif['vif'] = [variance_inflation_factor(tabela.values, i) for i in range(tabela.shape[1])]
    return vif

# %%
calc_vif(df)

# Regressão logística
# VIF -> n impacta  o resultado  da regressão logística 
# Mas, ao mesmo tempo, remover as variáveis com VIF alto, torna a equação mais simples
# Out:
#                   variaveis         vif
# 0                    HS_CPF    3.412182
# 1            QTDPESSOASCASA   31.690786
# 2            MENORRENDACASA    9.118081
# 3            MAIORRENDACASA   54.022669
# 4             SOMARENDACASA   40.028290
# 5            MEDIARENDACASA   66.867885
# 6            MAIORIDADECASA  371.082940
# 7            MENORIDADECASA  121.033315
# 8            MEDIAIDADECASA  694.286178
# 9         INDICMENORDEIDADE    1.247177
# 10        COBRANCABAIXOCASA    1.190985
# 11        COBRANCAMEDIOCASA    1.016701
# 12         COBRANCAALTACASA    1.010234
# 13  SEGMENTACAOFINBAIXACASA    1.197183
# 14  SEGMENTACAOFINMEDIACASA    1.004221
# 15      SEGMENTACAOALTACASA    1.000883
# 16         BOLSAFAMILIACASA    1.989690
# 17   FUNCIONARIOPUBLICOCASA    1.749915

# %%
# Remoção da coluna com maior VIF
df.drop('MEDIAIDADECASA', axis=1, inplace=True)

# %%
calc_vif(df)
# Out:
#                   variaveis        vif
# 0                    HS_CPF   3.409110
# 1            QTDPESSOASCASA  29.264081
# 2            MENORRENDACASA   9.105509
# 3            MAIORRENDACASA  53.887563
# 4             SOMARENDACASA  40.016857
# 5            MEDIARENDACASA  66.597892
# 6            MAIORIDADECASA  49.771072
# 7            MENORIDADECASA  22.550378
# 8         INDICMENORDEIDADE   1.245695
# 9         COBRANCABAIXOCASA   1.190981
# 10        COBRANCAMEDIOCASA   1.016700
# 11         COBRANCAALTACASA   1.010209
# 12  SEGMENTACAOFINBAIXACASA   1.197175
# 13  SEGMENTACAOFINMEDIACASA   1.004217
# 14      SEGMENTACAOALTACASA   1.000881
# 15         BOLSAFAMILIACASA   1.986836
# 16   FUNCIONARIOPUBLICOCASA   1.749914
